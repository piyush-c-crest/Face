# %%
import cv2
import mediapipe as mp

mp_face_mesh = mp.solutions.face_mesh

image = cv2.imread("front.png")
rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

with mp_face_mesh.FaceMesh(
    static_image_mode=True,
    max_num_faces=1,
    refine_landmarks=True
) as face_mesh:

    results = face_mesh.process(rgb)

    if results.multi_face_landmarks:
        landmarks = results.multi_face_landmarks[0]

        h, w = image.shape[:2]

        points = []

        for lm in landmarks.landmark:
            x = int(lm.x * w)
            y = int(lm.y * h)
            points.append((x, y))

        print("Total landmarks:", len(points))
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[1], line 7
#       4 mp_face_mesh = mp.solutions.face_mesh
#       6 image = cv2.imread("front.png")
# ----> 7 rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#       9 with mp_face_mesh.FaceMesh(
#      10     static_image_mode=True,
#      11     max_num_faces=1,
#      12     refine_landmarks=True
#      13 ) as face_mesh:
#      15     results = face_mesh.process(rgb)
#
# error: OpenCV(5.0.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
import mediapipe as mp

print(mp.__version__)
print(hasattr(mp, "solutions"))
